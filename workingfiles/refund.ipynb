# %%
import pandas as pd
import os
os.chdir("D:\合作店铺\中世\Basic Data")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\B'
# <>:3: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\jackyzhu\AppData\Local\Temp\ipykernel_19220\584708161.py:3: SyntaxWarning: invalid escape sequence '\B'
#   os.chdir("D:\合作店铺\中世\Basic Data")

# %%
data = pd.read_csv('seller_order.csv',index_col=0)

# %%
data['year_month'] = data['year'].astype(int).astype(str) + '_' + data['month'].astype(int).astype(str)

# %%
data =  data.groupby(['seller_id','year_month','marketplace'])['amazon_order_id'].nunique().reset_index()

# %%
data[(data['seller_id'] == 'A2ST06RBRNM2YB') & (data['marketplace'] == 'Amazon.com.mx')]
# Out:
#          seller_id year_month    marketplace  amazon_order_id
# 2   A2ST06RBRNM2YB    2022_10  Amazon.com.mx                4
# 7   A2ST06RBRNM2YB    2022_12  Amazon.com.mx                2
# 10  A2ST06RBRNM2YB     2022_2  Amazon.com.mx                2
# 13  A2ST06RBRNM2YB     2022_3  Amazon.com.mx                4
# 16  A2ST06RBRNM2YB     2022_4  Amazon.com.mx                4
# 19  A2ST06RBRNM2YB     2022_5  Amazon.com.mx                9
# 22  A2ST06RBRNM2YB     2022_6  Amazon.com.mx                4
# 25  A2ST06RBRNM2YB     2022_7  Amazon.com.mx                2
# 28  A2ST06RBRNM2YB     2022_8  Amazon.com.mx                2
# 33  A2ST06RBRNM2YB     2023_1  Amazon.com.mx                2
# 36  A2ST06RBRNM2YB    2023_10  Amazon.com.mx                3
# 39  A2ST06RBRNM2YB    2023_11  Amazon.com.mx                5
# 42  A2ST06RBRNM2YB    2023_12  Amazon.com.mx                4
# 45  A2ST06RBRNM2YB     2023_2  Amazon.com.mx                2
# ...

# %%
refund = pd.read_csv('D:\合作店铺\中世\Agg Data\中世_退款分析.csv',index_col=0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\jackyzhu\AppData\Local\Temp\ipykernel_19220\3547375940.py:1: SyntaxWarning: invalid escape sequence '\A'
#   refund = pd.read_csv('D:\合作店铺\中世\Agg Data\中世_退款分析.csv',index_col=0)

# %%
refund[refund['seller_id'] == 'A2ST06RBRNM2YB']
# Out:
#     year_month       seller_id         market        退货产品总价  退货产品数量  退单数量  \
# 0      2022_10  A2ST06RBRNM2YB      Amazon.ca   -281.233778      11    11
# 1      2022_10  A2ST06RBRNM2YB     Amazon.com  -4249.840000     208   201
# 11     2022_11  A2ST06RBRNM2YB      Amazon.ca   -598.381169      24    23
# 12     2022_11  A2ST06RBRNM2YB     Amazon.com  -6502.140000     267   261
# 23     2022_12  A2ST06RBRNM2YB      Amazon.ca  -2020.974336      65    65
# 24     2022_12  A2ST06RBRNM2YB     Amazon.com -12008.690000     408   401
# 25     2022_12  A2ST06RBRNM2YB  Amazon.com.mx      0.000000       3     2
# 37      2022_2  A2ST06RBRNM2YB      Amazon.ca   -136.578921       8     8
# 38      2022_2  A2ST06RBRNM2YB     Amazon.com  -2123.480000     102    99
# 39      2022_2  A2ST06RBRNM2YB  Amazon.com.mx    -42.025374       1     1
# 50      2022_3  A2ST06RBRNM2YB      Amazon.ca    -98.026036       4     4
# 51      2022_3  A2ST06RBRNM2YB     Amazon.com  -1868.870000     101    95
# ...
